# %% [markdown]
# # Happiness Data Set
#
# Research on Data Description:
# 1.Gallup World Poll:
# 2.Cantril ladder:Named after Andrew Cantrill,Psychologist.They are based on answers to the main life evaluation question asked in the poll. This is called the Cantril ladder.

# %%
import pandas as pd
ds=pd.read_csv("happiness_score_dataset.csv")
ds.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# Observation from Dataset:
# 1.Supervised ML as the target variable available ie"Happiness score". As the Target Variable (Happiness Score) is sum of all independent variable.
#
# 2.Regression to be applied as the given target is numerical & continuous.

# %%
ds.shape
# Out:
# (158, 12)

# %% [markdown]
# Observation: Data has 158 rows & 12 columns

# %%
ds.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Observation: Data do not have null values.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
sns.heatmap(ds.isnull())
plt.show()

# %% [markdown]
# Observation:Continuity in Heatmap shows Data do not have null values.

# %%
ds.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# Observation:
#
#     1.'Happiness Score' is target/dependent variable (Y) of data type: float.
#
#     2. Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual' are independent variable of data type: float.

# %%
ds.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# For ease, rename the column names
ds.columns=['Country', 'Region', 'Happiness Rank', 'Happiness Score',
       'Standard Error', 'Economy', 'Family',
       'Health', 'Freedom', 'Trust',
       'Generosity', 'Dystopia Residual']

# %%
ds.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy   Family   Health  Freedom    Trust  Generosity  \
# 0         0.03411  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1         0.04884  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2         0.03328  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3         0.03880  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4         0.03553  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    Dystopia Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# ...

# %% [markdown]
# EDA- Exploratory Data Analysis

# %% [markdown]
# Univariate Analysis

# %%
ds.plot(kind='box',subplots=True,layout=(2,5))
plt.show()

# %% [markdown]
# Observation:
# Columns like Standard error,Trust,Genorisity, Dystopia Residual have Outliers.
#
# Outliers of mentioned columns are displayed using Boxplot

# %%
co=["Standard Error","Family","Trust","Generosity","Dystopia Residual"]
for i in co:
    ds[i].plot.box()
    plt.show()

# %%
ds["Family"].plot.box()
plt.show()

# %%
ds["Trust"].plot.box()
plt.show()

# %%
ds["Generosity"].plot.box()
plt.show()

# %%
ds["Dystopia Residual"].plot.box()
plt.show()

# %%
ds.skew()
# Out:
# Happiness Rank       0.000418
# Happiness Score      0.097769
# Standard Error       1.983439
# Economy             -0.317575
# Family              -1.006893
# Health              -0.705328
# Freedom             -0.413462
# Trust                1.385463
# Generosity           1.001961
# Dystopia Residual   -0.238911
# dtype: float64

# %% [markdown]
# Observation:
# Columns: Standard Error,Family,Trust & Genorisity have Skewness.
#
# Skewness in data columns :Standard Error,Family,Trust & Genorisity is displayed using Histogram

# %%
col= ['Standard Error','Family','Trust','Generosity']
for i in col:
    plt.title(i)
    ds["Standard Error"].plot.hist()
    plt.show()

# %% [markdown]
# Bivariate Analysis:

# %%
col= ['Standard Error','Economy','Family','Health','Freedom','Trust','Generosity','Dystopia Residual']
for i in col:
    ds.plot.scatter([i],["Happiness Score"])
    plt.show()

# %% [markdown]
# Observation:
# Target Variable (Happiness Score) has:-
# 1.Strong Positive correlation with Economy,Family,Health.
# 2.Moderate Positive correlation with Freedom,Trust,Dystopia Residual.
# 3.Weak Correlation with Standard Error,Genorisity

# %% [markdown]
# MultiVariate Analysis:

# %%
corr=ds.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# Observation:
# Target Variable (Happiness Score) has:-
# 1.Strong Positive correlation with Economy,Family,Health.
# 2.Moderate Positive correlation with Freedom,Trust,Dystopia Residual.
# 3.Weak Correlation with Standard Error,Genorisity

# %%
#sns.pairplot(ds)

# %% [markdown]
# Observation:
# Skewness:
# Columns: Standard Error,Family,Trust & Genorisity have Skewness.
#
# Correlation:
# Target Variable (Happiness Score) has:-
# 1.Strong Positive correlation with Economy,Family,Health.
# 2.Moderate Positive correlation with Freedom,Trust,Dystopia Residual.
# 3.Weak Correlation with Standard Error,Genorisity

# %% [markdown]
# DATA Cleaning

# %%
# Check for null values
ds.isnull().sum()
# Out:
# Country              0
# Region               0
# Happiness Rank       0
# Happiness Score      0
# Standard Error       0
# Economy              0
# Family               0
# Health               0
# Freedom              0
# Trust                0
# Generosity           0
# Dystopia Residual    0
# dtype: int64

# %% [markdown]
# Observation: There are no null values.

# %%
# For further analysis column : Country, Region & Happiness rank are dropped.

# %%
df=ds.drop(columns=['Country',"Region","Happiness Rank"])
df.head()
# Out:
#    Happiness Score  Standard Error  Economy   Family   Health  Freedom  \
# 0            7.587         0.03411  1.39651  1.34951  0.94143  0.66557
# 1            7.561         0.04884  1.30232  1.40223  0.94784  0.62877
# 2            7.527         0.03328  1.32548  1.36058  0.87464  0.64938
# 3            7.522         0.03880  1.45900  1.33095  0.88521  0.66973
# 4            7.427         0.03553  1.32629  1.32261  0.90563  0.63297
#
#      Trust  Generosity  Dystopia Residual
# 0  0.41978     0.29678            2.51738
# 1  0.14145     0.43630            2.70201
# 2  0.48357     0.34139            2.49204
# 3  0.36503     0.34699            2.46531
# 4  0.32957     0.45811            2.45176

# %%
# To find outliers Using Z-score:
from scipy.stats import zscore
zscr=np.abs(zscore(df))

threshold=3
print(np.where(zscr>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
print("Shape before removing the outlier",df.shape)

dfnew=df[(zscr<3).all(axis=1)]
print("Shape after removing the outlier",dfnew.shape)
# Out:
# Shape before removing the outlier (158, 9)
# Shape after removing the outlier (149, 9)

# %%
dfnew.skew()
# Out:
# Happiness Score      0.169740
# Standard Error       1.243048
# Economy             -0.390657
# Family              -0.811340
# Health              -0.747711
# Freedom             -0.400867
# Trust                1.272530
# Generosity           0.654710
# Dystopia Residual   -0.021144
# dtype: float64

# %% [markdown]
# Observation: Here we see 9 rows have been removed. 5.6% of Data Loss. 94.4% Data retained

# %%
print("Skewness before removing outliers\n\n",df.skew())
# Out:
# Skewness before removing outliers
#
#  Happiness Score      0.097769
# Standard Error       1.983439
# Economy             -0.317575
# Family              -1.006893
# Health              -0.705328
# Freedom             -0.413462
# Trust                1.385463
# Generosity           1.001961
# Dystopia Residual   -0.238911
# dtype: float64

# %%
print("Skewness after removing outliers\n\n",dfnew.skew())
# Out:
# Skewness after removing outliers
#
#  Happiness Score      0.169740
# Standard Error       1.243048
# Economy             -0.390657
# Family              -0.811340
# Health              -0.747711
# Freedom             -0.400867
# Trust                1.272530
# Generosity           0.654710
# Dystopia Residual   -0.021144
# dtype: float64

# %%
corr=df.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr,annot=True)
plt.show()

# %% [raw]
# The skewness in column "Standard error" & "Generosity" can be treated as they have weak correlation.

# %%
#To check if if any negative values in data
for i in d.columns:
    if d[i].any()<0:
        print("true")
    else:
        print("false")

# %% [markdown]
# Observation: No negative values

# %%
#Removing skew using cube root from numpy
#All the values are now in range of -0.5 to 0.5
d=dfnew
d["Standard Error"]=np.sqrt(d["Standard Error"])
d["Generosity"]=np.sqrt(d["Generosity"])
d.skew()
# Out:
# Happiness Score      0.169740
# Standard Error       0.717347
# Economy             -0.390657
# Family              -0.811340
# Health              -0.747711
# Freedom             -0.400867
# Trust                1.272530
# Generosity          -0.285799
# Dystopia Residual   -0.021144
# dtype: float64

# %%
#Divide dependent & inpedendent data
dfnew.head()
# Out:
#    Happiness Score  Standard Error  Economy   Family   Health  Freedom  \
# 0            7.587        0.184689  1.39651  1.34951  0.94143  0.66557
# 1            7.561        0.220998  1.30232  1.40223  0.94784  0.62877
# 2            7.527        0.182428  1.32548  1.36058  0.87464  0.64938
# 3            7.522        0.196977  1.45900  1.33095  0.88521  0.66973
# 4            7.427        0.188494  1.32629  1.32261  0.90563  0.63297
#
#      Trust  Generosity  Dystopia Residual
# 0  0.41978    0.544775            2.51738
# 1  0.14145    0.660530            2.70201
# 2  0.48357    0.584286            2.49204
# 3  0.36503    0.589059            2.46531
# 4  0.32957    0.676838            2.45176

# %%
x=dfnew.drop(columns=["Happiness Score"])
y=dfnew["Happiness Score"]

# %%
#Model Training - Linear Regression

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 42,test_size=0.20)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (119, 8)
# (119,)
# (30, 8)
# (30,)

# %%
# Check the best random state
max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
    regr = LinearRegression()
    regr.fit(x_train,y_train)
    y_pred = regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
# Out:
# max r2 score corresponding to  42  is  0.9998387092513134

# %%
#Cross Validation to check overfitting
from sklearn.model_selection import cross_val_score
cross_val_score(LinearRegression(),x,y,cv=10,scoring="r2").mean()
# Out:
# 0.9025008058204298

# %%
#max r2 score we get at randmom state 56
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 42,test_size=0.20)
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print("r2 score is : ",r2_score(y_test,y_pred))
print("RMSE is : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is :  0.9998387092513134
# RMSE is :  0.013565352118005804

# %%
#Lets save above model
import joblib 
  
# Save the model as a pickle in a file 
joblib.dump(LinearRegression(), 'Happiness_dataset.joblib')
# Out:
# ['Happiness_dataset.joblib']
