# %% [markdown]
# # Avacado Project

# %% [raw]
# Problem Statement:
# Avocado is a fruit consumed by people heavily in the United States.
#
# Content
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# Date - The date of the observation
# AveragePrice - the average price of a single avocado
# type - conventional or organic
# year - the year
# Region - the city or region of the observation
# Total Volume - Total number of avocados sold
# 4046 - Total number of avocados with PLU 4046 sold
# 4225 - Total number of avocados with PLU 4225 sold
# 4770 - Total number of avocados with PLU 4770 sold
#
#
# Inspiration /Label
#
# Your task is to make a mode that can consider the data provided and predict the Average Price.

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Import dataset
df=pd.read_csv("G:\Data-Trained\Projects\Evaluation Project\EP3\Avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [raw]
# Observation:
# Supervised ML problem as target variable "Average Price" is provided.
# Target variable being numeric & continuous, Regression model to be developed.

# %%
#Drop column Unnamed: 0
df.drop(columns="Unnamed: 0",inplace=True)
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
#Check rows & columns
df.shape
#Rows=18249, Columns=13
# Out:
# (18249, 13)

# %%
#Check null values in individual columns
df.isnull().sum()
#No null values found in dataset
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
#Check the data type of features
df.info()
#Date,type & region are object type & other are numeric variables.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# # EDA

# %%
#Univariate analysis
#Check null values
sns.heatmap(df.isnull())
#No null values found
# Out:
# <AxesSubplot:>

# %%
#Check sales of feature "type" 
sns.countplot(x="type",data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [raw]
# Observation: Conventional & organic avocados both are equally preferred by customers.

# %%
#Check feature region
print(df["region"].value_counts())
plt.figure(figsize=(22,15))
sns.countplot(y="region",data=df)
# Out:
# Louisville             338
# Jacksonville           338
# NewOrleansMobile       338
# Midsouth               338
# GrandRapids            338
# SanDiego               338
# SouthCentral           338
# Sacramento             338
# NewYork                338
# HartfordSpringfield    338
# Charlotte              338
# Northeast              338
# Columbus               338
# MiamiFtLauderdale      338
# Spokane                338
# RaleighGreensboro      338
# Boise                  338
# Detroit                338
# Atlanta                338
# Pittsburgh             338
# Seattle                338
# Philadelphia           338
# Boston                 338
# Tampa                  338
# Southeast              338
# Nashville              338
# Albany                 338
# Roanoke                338
# RichmondNorfolk        338
# LasVegas               338
# Chicago                338
# West                   338
# DallasFtWorth          338
# BuffaloRochester       338
# ...

# %% [raw]
# Observation: Observation conducted at various regions are same and observations in WestTexNewMexico are marginally small.

# %%
#Bi variate analysis
#Check "Avg price" vs "type of Avocados"
sns.barplot(x="type",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %%
Observation: Organic Avocados are more expensive.

# %%
#Check "Avg price" vs "type of Avocados"
plt.figure(figsize=(22,15))
sns.barplot(y="region",x="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='region'>

# %% [raw]
# Observation: Avocados observed at region "HartfordSpringfield" & "San fransisco" have high average price.

# %%
#Feature engineering on feature "Date" to extract day & month.
import datetime
df["Date"]=pd.to_datetime(df["Date"])
df["Month"]=df["Date"].apply(lambda m:m.month)
df["Day"]=df["Date"].apply(lambda d:d.day)

# %%
#Check Average price distribution
plt.figure(figsize=(22,7))
sns.lineplot(x="Month",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %% [raw]
# Observation: Avocados are expensive in the month of September & October

# %%
plt.figure(figsize=(22,7))
sns.lineplot(x="year",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %% [raw]
# Observation: Avocado prices had shot up in year 2016 and was at its peak in 2017 year staring and further started to descend.

# %%
plt.figure(figsize=(22,15))
sns.barplot(y="region",x="Total Bags",data=df)
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='region'>

# %% [raw]
# Obsrvation: Regions which received highest bags for observation: West followed by south central,california & northeast

# %%
#Check correlation between features
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.093197
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black")
# Out:
# <AxesSubplot:>

# %% [raw]
# Observation: None of the numeric features in dataset are correlated to Average Price (target variable) but are rather correlated with eachother.

# %%
#Check for skewness
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# Month            0.106617
# Day              0.014310
# dtype: float64

# %%
#Uni-variate analysis
#Data distribution of Target variable
df["AveragePrice"].plot.hist()
#Data is normally distributed
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Data distribution of Independent variable
df["Total Volume"].plot.hist()
#Data is highly skewed to right
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["4046"].plot.hist()
#Data is highly skewed to right
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["4225"].plot.hist()
#Data is highly skewed to right
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["4770"].plot.hist()
#Data is highly skewed to right
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["Total Bags"].plot.hist()
#Data is highly skewed to right
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["Small Bags"].plot.hist()
#Data is highly skewed to right
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["Large Bags"].plot.hist()
#Data is highly skewed to right
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["XLarge Bags"].plot.hist()
#Data is highly skewed to right
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["year"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["Month"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["Day"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["AveragePrice"].plot.box()
#Outliers present in target variable
# Out:
# <AxesSubplot:>

# %%
#Check outliers
df["Total Volume"].plot.box()
#High number of outliers in data
# Out:
# <AxesSubplot:>

# %%
df["4046"].plot.box()
#High number of outliers in data
# Out:
# <AxesSubplot:>

# %%
df["4225"].plot.box()
#High number of outliers in data
# Out:
# <AxesSubplot:>

# %%
df["4770"].plot.box()
#High number of outliers in data
# Out:
# <AxesSubplot:>

# %%
df["Total Bags"].plot.box()
#High number of outliers in data
# Out:
# <AxesSubplot:>

# %%
df["Small Bags"].plot.box()
#High number of outliers in data
# Out:
# <AxesSubplot:>

# %%
df["Large Bags"].plot.box()
#High number of outliers in data
# Out:
# <AxesSubplot:>

# %%
df["XLarge Bags"].plot.box()
#High number of outliers in data
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Preprocessing

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany     12    6
# ...

# %%
print(df.shape)
# Out:
# (18249, 15)

# %%
#Feature "Date "can be dropped as its been converted to day & month
df.drop(columns=["Date"],inplace=True)

# %%
#Check feature "type"
df["type"].nunique()
#Only two unique values, can be handled using pd.dummies
# Out:
# 2

# %%
# Check feature "region"
df["region"].nunique()
#It will be not easy to handle "region" due tp 54 unique values.
# Out:
# 54

# %%
#Drop feature "region"
df.drop(columns=["region"],inplace=True)

# %%
df.shape
# Out:
# (18249, 13)

# %%
#Convert feature "type" to numeric 
df=pd.get_dummies(df,drop_first=True)

# %%
#Check shape
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  year  Month  Day  type_organic
# 0     8603.62       93.25          0.0  2015     12   27             0
# 1     9408.07       97.49          0.0  2015     12   20             0
# 2     8042.21      103.14          0.0  2015     12   13             0
# 3     5677.40      133.76          0.0  2015     12    6             0
# 4     5986.26      197.69          0.0  2015     11   29             0

# %%
#Handling outliers using Zscore method
from scipy.stats import zscore
zscr=np.abs(zscore(df))
threshold=3

#Lets check the presence of outlier
print("Shape before removing the outlier",df.shape)
dfnew=df[(zscr<3).all(axis=1)]
print("Shape after removing the outlier",dfnew.shape)
# Out:
# Shape before removing the outlier (18249, 13)
# Shape after removing the outlier (17651, 13)

# %%
#Check data loss
print("Percentage data loss=",((1-17651/18249)*100))
# Out:
# Percentage data loss= 3.276891884486821

# %%
#Divide the dataset into Dependent & Independent variables
df_x=dfnew.drop(columns=["AveragePrice"],axis=1)
y=dfnew["AveragePrice"]
print(df_x.shape,y.shape)
# Out:
# (17651, 12) (17651,)

# %%
#Check skewness in independent variables
df_x.skew()
# Out:
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# year            0.229976
# Month           0.107408
# Day             0.011778
# type_organic   -0.037741
# dtype: float64

# %%
#Now lets remove the skewness
for index in df_x.skew().index:
    if df_x.skew().loc[index]>0.5:
        df_x[index]=np.log1p(df_x[index])
    if df_x.skew().loc[index]<-0.5:
        df_x[index]=np.log1p(df_x[index])

# %%
#Skewness after skew adjustment
df_x.skew()
# Out:
# Total Volume   -0.049950
# 4046           -0.420273
# 4225           -2.253800
# 4770            0.068532
# Total Bags     -0.384493
# Small Bags     -3.556827
# Large Bags     -1.488728
# XLarge Bags     1.216238
# year            0.229976
# Month           0.107408
# Day             0.011778
# type_organic   -0.037741
# dtype: float64

# %%
#Data scaling to achieve more accuracy
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)
x
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.061962 -0.587318  0.454779 -0.246207   -0.473426   -0.036080
# 1         -0.134302 -0.719464  0.403650 -0.199437   -0.431908   -0.009059
# 2          0.218235 -0.668997  0.627160 -0.001478   -0.504018   -0.056637
# 3          0.033021 -0.560308  0.525116 -0.145897   -0.661685   -0.164974
# 4         -0.167601 -0.616931  0.398953 -0.135308   -0.632653   -0.148243
# ...             ...       ...       ...       ...         ...         ...
# 17646     -0.670586 -0.378245 -0.628522 -1.215018   -0.268139    0.088244
# 17647     -0.765474 -0.544515 -0.347523 -1.215018   -0.443885   -0.024455
# 17648     -0.769503 -0.544458 -0.461130  0.424488   -0.437415   -0.010865
# 17649     -0.694596 -0.468195 -0.394622  0.424171   -0.365019    0.035454
# 17650     -0.659562 -0.271708 -0.475022  0.132697   -0.322543    0.063022
#
#        Large Bags  XLarge Bags      year     Month       Day  type_organic
# ...

# %%
#Tried Principal Component Analysis to improve R2 score. But R2 score not improved.
from sklearn.decomposition import PCA
pca=PCA(n_components=9)
pc_x=pca.fit_transform(x)

#Information retained in data after dimensionality reduction
print("Percentage info retained in data=",(sum(pca.explained_variance_ratio_)*100))
# Out:
# Percentage info retained in data= 96.97122108331688

# %% [markdown]
# # Check Best Random state

# %%
#Check best random state: Considering r2 metrics
#User-defined function to find r2 score:
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#User defined function for cross-validation
from sklearn.model_selection import cross_val_score
def cross_val(model,x,y):
    cv=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",cv.mean())
    print(cv)

# %%
#As datapoints are huge in number, we will check model for best "r2- score" then proceed with hyper-parameter tuning.

# %% [markdown]
# # 1. Decision Tree Regressor

# %%
#Decision tree regressor
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dt_r2=maxr2_score(dtr,x,y)
# Out:
# max r2 score corresponding to  85  is  0.7520342985295759

# %%
#Cross validation (Decision tree)
cross_val(dtr,x,y)
# Out:
# Mean r2 score for regressor:  -0.2821832411881732
# [-0.81681569  0.15555115  0.24530351 -0.42313599 -0.57181919]

# %% [markdown]
# # 2.K-Nearest Neighbor Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
r_state=maxr2_score(knr,x,y)
# Out:
# max r2 score corresponding to  69  is  0.7751335365081258

# %%
#Cross validation (KNN Classifier)
cross_val(knr,x,y)
# Out:
# Mean r2 score for regressor:  0.1281493148845964
# [-0.25853696  0.3880087   0.55707007  0.02545814 -0.07125338]

# %% [markdown]
# # 3. Support Vector Regressor

# %%
from sklearn.svm import SVR
svr=SVR()
r_state=maxr2_score(svr,x,y)
# Out:
# max r2 score corresponding to  82  is  0.7731254587424399

# %%
#Cross validation (SVR)
cross_val(svr,x,y)
# Out:
# Mean r2 score for regressor:  0.1975508060924686
# [-0.31383442  0.59459288  0.47625254  0.31248393 -0.0817409 ]

# %% [markdown]
# # 4.Random Forest Regressor

# %%
#Check maxr2_score function
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
r_state=maxr2_score(rfr,x,y)
# Out:
# max r2 score corresponding to  79  is  0.8807473205666203

# %%
#Cross validation (Random Forest)
cross_val(rfr,x,y)
# Out:
# Mean r2 score for regressor:  0.21525567059452907
# [-0.27167239  0.48179284  0.5915178   0.30110835 -0.02646824]

# %% [markdown]
# # 5.AdaBoost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor
adr=AdaBoostRegressor()
r_state=maxr2_score(adr,x,y)
# Out:
# max r2 score corresponding to  85  is  0.5836436808049543

# %%
#Cross validation (Adaboost Regressor)
cross_val(adr,x,y)
# Out:
# Mean r2 score for regressor:  0.06024754041897458
# [-0.75219924  0.3050368   0.52403244  0.07453372  0.14983398]

# %% [markdown]
# # 6. Linear Regression

# %%
#Linear Regressor
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
r_state=maxr2_score(lr,x,y)
# Out:
# max r2 score corresponding to  82  is  0.5374794354590863

# %%
#Cross validation (Linear Regressor)
cross_val(lr,x,y)
# Out:
# Mean r2 score for regressor:  0.14563879034222355
# [-0.29951655  0.18275253  0.44441238  0.18080985  0.21973573]

# %% [markdown]
# # Random forest is the best performing model

# %%
#Hyper Parameter tuning for forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,500]}
rgr = GridSearchCV(rfr, parameters, cv=5)
rgr.fit(x, y)
rgr.best_params_
# Out:
# {'n_estimators': 500}

# %%
#Random Forest is best model and will be saved
# Random state= 79
# Parameter={'n_estimators': 500}
from sklearn.metrics import mean_squared_error,mean_absolute_error
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=79)
rfr=RandomForestRegressor(n_estimators=500)
rfr.fit(x_train,y_train)
y_pred=rfr.predict(x_test)
print("R2 score=",r2_score(y_test,y_pred))
print("RMSE=",np.sqrt(mean_squared_error(y_test,y_pred)))
print("Mean abs error=",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score= 0.8816036752481033
# RMSE= 0.13228993761687138
# Mean abs error= 0.09539564995751912

# %%
import joblib
joblib.dump(rfr,"Avocado_regression.joblib")
# Out:
# ['Avocado_regression.joblib']
